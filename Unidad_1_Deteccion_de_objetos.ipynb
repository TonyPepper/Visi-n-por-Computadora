# %% [markdown]
# YoloV8n

# %%
# %pip install ultralytics
# Librería mediapy para mostrar videos
# %pip install -q mediapy
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.46 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (AMD EPYC 7B12)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/107.7 GB disk)

# %%
# Importamos las librerías a utilizar
import cv2
from ultralytics import YOLO
from IPython.display import Image

# Load the pre-trained YOLOv8 model
model = YOLO('yolov8n')  # This will automatically download the model weights

# Perform inference
source_img = cv2.imread('/content/home.JPG')
results = model(source_img)

# Visualize the results on the frame
annotated_frame = results[0].plot()

# Guardamos el resultado en JPG
cv2.imwrite('home_results.jpg', annotated_frame)

# Mostramos el resultado en Colab
Image('home_results.jpg')
# Out:
# 0: 384x640 1 backpack, 5 chairs, 1 potted plant, 1 dining table, 2 tvs, 1 laptop, 137.4ms
# Speed: 3.8ms preprocess, 137.4ms inference, 783.2ms postprocess per image at shape (1, 3, 384, 640)
